# %%
# 연습문제 1 : 네이버 사이트 자동 검색하기
#Step 1. 필요한 모듈을 로딩합니다
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
import time   

#Step 2. 사용자에게 검색 관련 정보들을 입력 받습니다.
print("=" *100)
print(" 이 크롤러는 네이버 사이트의 자동 검색용 웹크롤러입니다.")
print("=" *100)
query_txt = input('1.수집할 자료의 키워드는 무엇입니까?(예: 서진수 빅데이터): ')
print("\n")

#Step 3. 크롬 드라이버 설정 및 웹 페이지 열기
s = Service("c:/py_temp/chromedriver.exe")
driver = webdriver.Chrome(service=s)

url = 'https://www.naver.com/'
driver.get(url)
time.sleep(3)
driver.maximize_window()

#Step 4. 자동으로 검색어 입력 후 조회하기
element = driver.find_element(By.ID,'query')
driver.find_element(By.ID,'query').click( )
element.send_keys(query_txt)
element.send_keys("\n")

#Step 5.뉴스 선택하기
driver.find_element(By.LINK_TEXT,'뉴스').click()
time.sleep(2)

#Step 6.Beautiful Soup 로 본문 내용만 추출하기
from bs4 import BeautifulSoup
html_1 = driver.page_source #현재 페이지의 전체 소스코드를 다 가져오기
soup_1 = BeautifulSoup(html_1, 'html.parser')

content_1 = soup_1.find('ul','list_news').find_all('li')
for i in content_1 :
    print(i.get_text().replace("\n"," ").strip())
    print("\n")

#Step 7. 표준 출력 방향을 바꾸어 txt 파일에 저장하기
import sys 
f_name = input('결과를 저장할 파일명을 쓰세요(예: c:\\py_temp\\naver_news.txt): ')

orig_stdout = sys.stdout
file = open(f_name , 'a' , encoding='UTF-8')
sys.stdout = file  #모니터에 출력하지 말고 file 에 출력해라

for i in content_1 :
    print(i.get_text().replace("\n",""))

file.close()    
sys.stdout = orig_stdout  #원래대로 변경 - 다시 화면에 출력시켜라    

print('요청하신 데이터 수집 작업이 정상적으로 완료되었습니다')
print('수집된 결과는 %s 에 저장되었습니다' %f_name)

#Step 8. open -> write -> close 방식으로  txt 파일에 저장하기
f_name_2 = 'c:\\py_temp\\naver_news_2.txt' 

file = open(f_name_2 , 'a' , encoding='UTF-8')

for i in content_1 :
    file.write(i.get_text()+'\n')

file.close()      

print('요청하신 데이터 수집 작업이 정상적으로 완료되었습니다')
print('수집된 결과는 %s 에 저장되었습니다' %f_name_2)
# Out:
# ====================================================================================================
#  이 크롤러는 네이버 사이트의 자동 검색용 웹크롤러입니다.
# ====================================================================================================
# 1.수집할 자료의 키워드는 무엇입니까?(예: 서진수 빅데이터): 가치평가
#
#
# 문서 저장하기  Keep에 저장 Keep 바로가기  조선비즈언론사 선정14시간 전네이버뉴스 통신비 잘 내면 대출 한도 상향… 통신3사 신용평가 합작법인 설립   또 합작법인을 통해 비금융 신용평가사업을 시작으로 데이터 사업 활성화의 기반을 조성하고, 새로운 고객가치 창출을 위한 신규사업을 발굴하기 위해 힘을 모을 계획이다. 합작법인 지분과 관련해 통신 3사가 각 26...       연합뉴스15시간 전네이버뉴스 통신3사 첫 합작법인으로 비금융 신용평가서비스 설립 진행중     뉴스핌14시간 전 이통3사, 금융약자 돕는 신용평가 합작법인 설립     아시아투데이14시간 전 통신3사, 금융소외계층 위한 신용평가 합작법인 추진     뉴데일리14시간 전 이통3사, 금융소외계층 대상 '신용평가 합작법인' 설립 나서  관련뉴스 8건 전체보기
#
#
# 연합뉴스15시간 전네이버뉴스 통신3사 첫 합작법인으로 비금융 신용평가서비스 설립 진행중
#
#
# 뉴스핌14시간 전 이통3사, 금융약자 돕는 신용평가 합작법인 설립
#
#
# 아시아투데이14시간 전 통신3사, 금융소외계층 위한 신용평가 합작법인 추진
#
#
# 뉴데일리14시간 전 이통3사, 금융소외계층 대상 '신용평가 합작법인' 설립 나서
#
#
# 문서 저장하기  Keep에 저장 Keep 바로가기  SBS Biz언론사 선정14시간 전네이버뉴스 통신3사, 신용평가 합작법인 만든다…"통신 정보로 신용 판단"   신용평가서비스를 활용한다"고 밝혔습니다. 합작법인은 금융이력 부족으로 금융서비스 이용에 제한이... ESG가치 실현, 새로운 고객가치 창출을 목표로 합작법인의 성공적인 설립과 사업을 위해 지속적으로 노력할...       뉴스114시간 전네이버뉴스 통신3사, 신용평가 합작법인 만든다…“금융약자 돕겠다”     브릿지경제15시간 전 통신 3사, 금융약자 돕는 신용평가 합작법인 설립 추진     UPI뉴스14시간 전 통신 3사, 금융약자 위해 신용평가 합작법인 설립 추진
#
#
# 뉴스114시간 전네이버뉴스 통신3사, 신용평가 합작법인 만든다…“금융약자 돕겠다”
#
#
# 브릿지경제15시간 전 통신 3사, 금융약자 돕는 신용평가 합작법인 설립 추진
#
#
# UPI뉴스14시간 전 통신 3사, 금융약자 위해 신용평가 합작법인 설립 추진
#
#
# 문서 저장하기  Keep에 저장 Keep 바로가기  이코노미스트1일 전네이버뉴스 KB국민은행, 자체 지식재산(IP) 가치평가로 중소기업 지원   KB국민은행은 자체적으로 지식재산(IP: Intellectual Property) 가치평가를 시행한다고 3일 밝혔다. KB국민은행은 지난 4월 특허청으로부터 ‘발명의 평가기관’으로 지정된 이후 자체 지식재산(IP) 가치평가를 위한 내부...       머니S1일 전네이버뉴스 KB국민은행, 자체 지식재산 가치평가 시행     데일리한국1일 전 KB국민은행, 자체 지식재산(IP) 가치평가 시행     조선비즈1일 전네이버뉴스 KB국민은행, 자체 지식재산(IP) 가치평가 시행     MTN1일 전 IP도 대출 담보…국민은행, 지식재산 가치평가  관련뉴스 28건 전체보기
#
#
# 머니S1일 전네이버뉴스 KB국민은행, 자체 지식재산 가치평가 시행
#
#
# 데일리한국1일 전 KB국민은행, 자체 지식재산(IP) 가치평가 시행
#
#
# 조선비즈1일 전네이버뉴스 KB국민은행, 자체 지식재산(IP) 가치평가 시행
#
#
# MTN1일 전 IP도 대출 담보…국민은행, 지식재산 가치평가
#
#
# 문서 저장하기  Keep에 저장 Keep 바로가기  파이낸셜뉴스22시간 전네이버뉴스 부천시 하수도공기업 경영평가 전국1등   이번 평가는 전국 257개 지방공기업을 대상으로 이뤄졌으며 지속가능 경영, 경영 성과, 사회적 가치 등 3개 분야 20여개 평가지표가 활용된 정량-정성 평가와 현지확인 평가를 반영했다. 부천시는 코로나19 여파로...       아주경제14시간 전 경산시, 2022년 지방 하수도 경영평가 우수등급 받아
#
#
# 아주경제14시간 전 경산시, 2022년 지방 하수도 경영평가 우수등급 받아
#
#
# 문서 저장하기  Keep에 저장 Keep 바로가기  뉴시스언론사 선정18시간 전네이버뉴스 'K바이오, 버블 논란 벗어나 M&A서 가치 찾아야'   기사내용 요약 ‘바이오기업가치평가...바이오, 과연 버블인가’ 유효상 유니콘경영연구원장 3일 2020세션 발표 삼일 서용범·BNH인베스트 강지수 '한 목소리' 【서울=뉴시스】황재희 기자 = 최근 국내 바이오 주가가...
#
#
# 문서 저장하기  Keep에 저장 Keep 바로가기  더팩트1일 전네이버뉴스 CJ올리브영, IPO 연기…"기업 가치 평가 어려워"   CJ올리브영 관계자는 "현재 시장 상황을 고려했을 때 기업가치를 제대로 평가 받기 어렵다는 주주 의견이 있었다"고 설명했다. ​ 한편, CJ올리브영의 상장은 CJ그룹의 경영승계와도 맞물려있다는 평가가 지배적이다....       조선비즈언론사 선정1일 전네이버뉴스 “코로나로 뛴 기업가치 無의미” 플랫폼 투자심사 개점휴업…IPO ‘신중모드...
#
#
# 조선비즈언론사 선정1일 전네이버뉴스 “코로나로 뛴 기업가치 無의미” 플랫폼 투자심사 개점휴업…IPO ‘신중모드...
#
#
# 문서 저장하기  Keep에 저장 Keep 바로가기  한국경제13시간 전네이버뉴스 빅데이터로 예술품 가치 평가…신세계인터내셔날, '아트빌리지' 선보여   신세계인터내셔날은 자체 쇼핑몰 에스아이빌리지가 빅데이터를 활용한 아티스트 큐레이션 플랫폼 '아트빌리지'를 론칭했다고 4일 밝혔다. 아트빌리지는 빅데이터를 기반으로 성장 잠재력이 높은 작가를 선정해 작품과...
#
#
# 문서 저장하기  Keep에 저장 Keep 바로가기  데일리안1일 전네이버뉴스 KB국민은행, 자체 IP 가치평가 시행   KB국민은행은 자체적으로 지식재산(IP) 가치평가를 시행한다고 3일 밝혔다. KB국민은행은 지난 4월 특허청으로부터 ‘발명의 평가기관’으로 지정된 이후 자체 IP 가치평가를 위한 내부 제도 및 프로세스 재정비...       뉴시스1일 전네이버뉴스 KB국민은행, 자체 지식재산 가치평가 시행     매일신문1일 전네이버뉴스 KB국민은행, 자체 IP 가치평가 시행...중소기업 성장 지원     이투데이1일 전 KB국민은행, 자체 지식재산(IP) 가치평가 시행     신아일보1일 전 KB국민은행, 자체 IP 가치평가 시행  관련뉴스 6건 전체보기
#
#
# 뉴시스1일 전네이버뉴스 KB국민은행, 자체 지식재산 가치평가 시행
#
#
# 매일신문1일 전네이버뉴스 KB국민은행, 자체 IP 가치평가 시행...중소기업 성장 지원
#
#
# 이투데이1일 전 KB국민은행, 자체 지식재산(IP) 가치평가 시행
#
#
# 신아일보1일 전 KB국민은행, 자체 IP 가치평가 시행
#
#
# 문서 저장하기  Keep에 저장 Keep 바로가기  동아일보9시간 전네이버뉴스 통신3社, 신용평가 합작법인 설립 추진…‘신 파일러’ 금융 접근 돕는다   신용평가 모델이 시장에 자리잡을 수 있도록 협력할 예정이다. 이밖에도 5개사는 합작법인을 통해 이번 사업을 시작으로 데이터 사업 활성화 기반을 조성하고, 이후 새로운 고객가치 창출을 위한 신규사업 발굴에도...       파이낸셜뉴스언론사 선정5시간 전네이버뉴스 통신3사 첫 합작 신용평가사... "금융 소외계층 대출 지원 확대"     스포츠경향15시간 전네이버뉴스 통신3사, 금융약자 돕는 신용평가합작법인 만든다     스포츠서울12시간 전네이버뉴스 통신3사, 금융약자 돕는 '신용평가 합작법인' 공동 설립     부산일보13시간 전네이버뉴스 통신3사, 금융약자 돕는 신용평가 합작법인 만든다  관련뉴스 14건 전체보기
#
#
# 파이낸셜뉴스언론사 선정5시간 전네이버뉴스 통신3사 첫 합작 신용평가사... "금융 소외계층 대출 지원 확대"
#
#
# 스포츠경향15시간 전네이버뉴스 통신3사, 금융약자 돕는 신용평가합작법인 만든다
#
#
# 스포츠서울12시간 전네이버뉴스 통신3사, 금융약자 돕는 '신용평가 합작법인' 공동 설립
#
#
# 부산일보13시간 전네이버뉴스 통신3사, 금융약자 돕는 신용평가 합작법인 만든다
#
#
# 문서 저장하기  Keep에 저장 Keep 바로가기  쿠키뉴스14시간 전 “기업 가치 평가 어려워” CJ올리브영, IPO 중단   CJ올리브영 관계자는 “현재 시장 상황을 고려했을 때 기업가치를 제대로 평가받기 어렵다는 주주 의견이 있었다”고 밝혔다. 당초 CJ올리브영은 지난해 11월 주관사를 선정하고 연내 상장을 위한 작업을 진행해왔다....

# %%
# 연습문제 2 : 다음 사이트 자동 검색하기
#Step 1. 필요한 모듈을 로딩합니다
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
import time   

#Step 2. 사용자에게 검색 관련 정보들을 입력 받습니다.
print("=" *100)
print(" 이 크롤러는 다음 사이트의 자동 검색용 웹크롤러입니다.")
print("=" *100)
query_txt = input('1.수집할 자료의 키워드는 무엇입니까?(예: 서진수 빅데이터): ')
print("\n")

#Step 3. 크롬 드라이버 설정 및 웹 페이지 열기
s = Service("c:/py_temp/chromedriver.exe")
driver = webdriver.Chrome(service=s)

url = 'https://www.daum.net/'
driver.get(url)
time.sleep(3)
driver.maximize_window()

#Step 4. 자동으로 검색어 입력 후 조회하기
element = driver.find_element(By.ID,'q')
driver.find_element(By.ID,'q').click( )
element.send_keys(query_txt)
element.send_keys("\n")

#Step 5.뉴스 선택하기
driver.find_element(By.LINK_TEXT,'뉴스').click()
time.sleep(2)

#Step 6.Beautiful Soup 로 본문 내용만 추출하기
from bs4 import BeautifulSoup
html_1 = driver.page_source #현재 페이지의 전체 소스코드를 다 가져오기
soup_1 = BeautifulSoup(html_1, 'html.parser')

content_1 = soup_1.find('ul','list_news').find_all('li')
for i in content_1 :
    print(i.get_text().replace("\n"," ").strip())
    print("\n")

#Step 7. 표준 출력 방향을 바꾸어 txt 파일에 저장하기
import sys 
f_name = input('결과를 저장할 파일명을 쓰세요(예: c:\\py_temp\\daum_news.txt): ')

orig_stdout = sys.stdout
file = open(f_name , 'a' , encoding='UTF-8')
sys.stdout = file  #모니터에 출력하지 말고 file 에 출력해라

for i in content_1 :
    print(i.get_text().replace("\n",""))

file.close()    
sys.stdout = orig_stdout  #원래대로 변경 - 다시 화면에 출력시켜라    

print('요청하신 데이터 수집 작업이 정상적으로 완료되었습니다')
print('수집된 결과는 %s 에 저장되었습니다' %f_name)

# %%
#Step 8. open -> write -> close 방식으로  txt 파일에 저장하기
f_name_2 = 'c:\\py_temp\\daum_news_2.txt' 

file = open(f_name_2 , 'a' , encoding='UTF-8')

for i in content_1 :
    file.write(i.get_text()+'\n')

file.close()      

print('요청하신 데이터 수집 작업이 정상적으로 완료되었습니다')
print('수집된 결과는 %s 에 저장되었습니다' %f_name_2)

# %%
#연습문제 3: 대한민국 구석구석사이트 자동 검색하기
    
#Step 1. 필요한 모듈을 로딩합니다
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
import time 

#Step 2. 사용자에게 검색 관련 정보들을 입력 받습니다.
print("=" *100)
print(" 이 크롤러는 대한민국 구석구석 사이트의 자동 검색용 웹크롤러입니다.")
print("=" *100)
query_txt = input('1.수집할 자료의 키워드는 무엇입니까?(예: 제주도): ')
print("\n")

#Step 3. 크롬 드라이버 설정 및 웹 페이지 열기
s = Service("c:/py_temp/chromedriver.exe")
driver = webdriver.Chrome(service=s)

url = 'https://korean.visitkorea.or.kr'
driver.get(url)
time.sleep(3)
driver.maximize_window()

# 팝업 안내창 모두 닫기
main = driver.window_handles 
for handle in main: 
    if handle != main[0]: 
        driver.switch_to_window(handle) 
        driver.close()

# 원래 창으로 돌아가기
driver.switch_to.window(driver.window_handles[0])    
       
#Step 4. 자동으로 검색어 입력 후 조회하기
element = driver.find_element(By.ID,'inp_search')
driver.find_element(By.ID,'inp_search').click( )
element.send_keys(query_txt)
element.send_keys("\n")

# %%
# 첫번째 방법
from bs4 import BeautifulSoup
time.sleep(1)
full_html = driver.page_source
soup = BeautifulSoup(full_html, 'html.parser')

content_list = soup.find('div','area_sWordList').get_text()
print(content_list)

# %%
# 두번째 방법

time.sleep(1)
full_html = driver.page_source
soup = BeautifulSoup(full_html, 'html.parser')
content_list = soup.find('div','area_sWordList').find_all('li')

for i in content_list:
    print(i.get_text())

# %%
# 세번째 방법

time.sleep(1)
full_html = driver.page_source
soup = BeautifulSoup(full_html, 'html.parser')
content_list = soup.find('div','area_sWordList').find_all('li')

for i in content_list:
    txt = i.find('em').get_text()
    print(txt)

# %%
#표준 출력 방향을 바꾸어 txt 파일에 저장하기
import sys 
f_name = input('결과를 저장할 파일명을 쓰세요(예: c:\\py_temp\\korea.txt): ')

orig_stdout = sys.stdout
file = open(f_name , 'a' , encoding='UTF-8')
sys.stdout = file  #모니터에 출력하지 말고 file 에 출력해라

for i in content_list:
    txt = i.find('em').get_text()
    print(txt)

file.close()    
sys.stdout = orig_stdout  #원래대로 변경 - 다시 화면에 출력시켜라    

print('요청하신 데이터 수집 작업이 정상적으로 완료되었습니다')
print('수집된 결과는 %s 에 저장되었습니다' %f_name)

# %%
#open -> write -> close 방식으로  txt 파일에 저장하기
f_name_2 = 'c:\\py_temp\\korea_2.txt' 

file = open(f_name_2 , 'a' , encoding='UTF-8')

for i in content_list :
    file.write(i.find('em').get_text()+'\n')

file.close()      

print('요청하신 데이터 수집 작업이 정상적으로 완료되었습니다')
print('수집된 결과는 %s 에 저장되었습니다' %f_name_2)

# %%
#연습문제 4: 대한민국 구석구석사이트 자동 검색하여 텍스트 추출 후 저장하기
    
#Step 1. 필요한 모듈을 로딩합니다
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
import time 

#Step 2. 사용자에게 검색 관련 정보들을 입력 받습니다.
print("=" *100)
print(" 이 크롤러는 대한민국 구석구석 사이트의 자동 검색용 웹크롤러입니다.")
print("=" *100)
query_txt = input('1.수집할 자료의 키워드는 무엇입니까?(예: 제주도): ')
print("\n")

#Step 3. 크롬 드라이버 설정 및 웹 페이지 열기
s = Service("c:/py_temp/chromedriver.exe")
driver = webdriver.Chrome(service=s)

url = 'https://korean.visitkorea.or.kr'
driver.get(url)
time.sleep(3)
driver.maximize_window()

# 팝업 안내창 모두 닫기
main = driver.window_handles 
for handle in main: 
    if handle != main[0]: 
        driver.switch_to_window(handle) 
        driver.close()

# 원래 창으로 돌아가기
driver.switch_to.window(driver.window_handles[0])    
       
#Step 4. 자동으로 검색어 입력 후 조회하기
element = driver.find_element(By.ID,'inp_search')
driver.find_element(By.ID,'inp_search').click( )
element.send_keys(query_txt)
element.send_keys("\n")

# %%
# Step 5. 검색된 목록을 추출합니다
from bs4 import BeautifulSoup
full_html = driver.page_source
soup = BeautifulSoup(full_html, 'html.parser')

content_list = soup.find('ul','list_thumType type1').find_all('li')
for a in content_list :
    print(a.get_text())
    print()

# %%
#표준 출력 방향을 바꾸어 txt 파일에 저장하기
import sys 
f_name = input('결과를 저장할 파일명을 쓰세요(예: c:\\py_temp\\korea_3.txt): ')

orig_stdout = sys.stdout
file = open(f_name , 'a' , encoding='UTF-8')
sys.stdout = file  #모니터에 출력하지 말고 file 에 출력해라

for a in content_list :
    print(a.get_text())
    print()

file.close()    
sys.stdout = orig_stdout  #원래대로 변경 - 다시 화면에 출력시켜라    

print('요청하신 데이터 수집 작업이 정상적으로 완료되었습니다')
print('수집된 결과는 %s 에 저장되었습니다' %f_name)

# %%
#open -> write -> close 방식으로  txt 파일에 저장하기
f_name_2 = 'c:\\py_temp\\korea_4.txt' 

file = open(f_name_2 , 'a' , encoding='UTF-8')

for i in content_list :
    file.write(i.get_text()+'\n')

file.close()      

print('요청하신 데이터 수집 작업이 정상적으로 완료되었습니다')
print('수집된 결과는 %s 에 저장되었습니다' %f_name_2)
